# %% [markdown]
# ## Importing the libraries required.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Assigning the right column names and read into the DataFrame.

# %%
df = pd.read_csv("dataset.csv", delimiter='^', index_col=0, names=['Open','High','Low','Close','Volume','Market Cap'])
df.head()
# Out:
#                              Open            High            Low  \
# Date                         Open            High            Low
# Jun 22, 2018             6,737.88        6,747.08       6,006.60
# Jun 21, 2018             6,780.09        6,810.94       6,715.17
# Jun 20, 2018             6,770.76        6,821.56       6,611.88
# Jun 19, 2018             6,742.39        6,822.50       6,709.92
#
#                        Close              Volume               Market Cap
# Date                   Close              Volume               Market Cap
# Jun 22, 2018        6,083.69       5,079,810,000          115,269,000,000
# Jun 21, 2018        6,729.74       3,529,130,000          115,977,000,000
# Jun 20, 2018        6,776.55       3,888,640,000          115,804,000,000
# Jun 19, 2018        6,769.94       4,057,030,000          115,306,000,000

# %% [markdown]
# ### Check for correct column names to see if they're without any extra spaces.

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df = df.iloc[1:,:]
# Out:
#                        Open           High            Low          Close  \
# Jun 22, 2018       6,737.88       6,747.08       6,006.60       6,083.69
# Jun 21, 2018       6,780.09       6,810.94       6,715.17       6,729.74
# Jun 20, 2018       6,770.76       6,821.56       6,611.88       6,776.55
# Jun 19, 2018       6,742.39       6,822.50       6,709.92       6,769.94
# Jun 18, 2018       6,510.07       6,781.14       6,446.68       6,734.82
# Jun 17, 2018       6,545.53       6,589.11       6,499.27       6,499.27
# Jun 16, 2018       6,455.45       6,592.49       6,402.29       6,550.16
# Jun 15, 2018       6,674.08       6,681.08       6,433.87       6,456.58
# Jun 14, 2018       6,342.75       6,707.14       6,334.46       6,675.35
# Jun 13, 2018       6,596.88       6,631.66       6,285.63       6,349.90
# Jun 12, 2018       6,905.82       6,907.96       6,542.08       6,582.36
# Jun 11, 2018       6,799.29       6,910.18       6,706.63       6,906.92
# Jun 10, 2018       7,499.55       7,499.55       6,709.07       6,786.02
# Jun 09, 2018       7,632.52       7,683.58       7,531.98       7,531.98
# Jun 08, 2018       7,685.14       7,698.19       7,558.40       7,624.92
# Jun 07, 2018       7,650.82       7,741.27       7,650.82       7,678.24
# Jun 06, 2018       7,625.97       7,680.43       7,502.01       7,653.98
# Jun 05, 2018       7,500.90       7,643.23       7,397.00       7,633.76
# Jun 04, 2018       7,722.53       7,753.82       7,474.04       7,514.47
# Jun 03, 2018       7,632.09       7,754.89       7,613.04       7,720.25
# Jun 02, 2018       7,536.72       7,695.83       7,497.26       7,643.45
# Jun 01, 2018       7,500.70       7,604.73       7,407.34       7,541.45
# May 31, 2018       7,406.15       7,608.90       7,361.13       7,494.17
# May 30, 2018       7,469.73       7,573.77       7,313.60       7,406.52
# May 29, 2018       7,129.46       7,526.42       7,090.68       7,472.59
# May 28, 2018       7,371.31       7,419.05       7,100.89       7,135.99
# May 27, 2018       7,362.08       7,381.74       7,270.96       7,368.22
# May 26, 2018       7,486.48       7,595.16       7,349.12       7,355.88
# May 25, 2018       7,592.30       7,659.14       7,392.65       7,480.14
# May 24, 2018       7,561.12       7,738.60       7,331.14       7,587.34
# ...                     ...            ...            ...            ...
# May 27, 2013         133.50         135.47         124.70         129.75
# May 26, 2013         131.99         136.00         130.62         133.48
# May 25, 2013         133.10         133.22         128.90         131.98
# May 24, 2013         126.30         133.85         125.72         133.20
# May 23, 2013         123.80         126.93         123.10         126.70
# May 22, 2013         122.89         124.00         122.00         123.89
# May 21, 2013         122.02         123.00         121.21         122.88
# May 20, 2013         122.50         123.62         120.12         122.00
# May 19, 2013         123.21         124.50         119.57         121.99
# May 18, 2013         123.50         125.25         122.30         123.50
# May 17, 2013         118.21         125.30         116.57         123.02
# May 16, 2013         114.22         118.76         112.20         118.76
# May 15, 2013         111.40         115.81         103.50         114.22
# May 14, 2013         117.98         119.80         110.25         111.50
# May 13, 2013         114.82         118.70         114.50         117.98
# May 12, 2013         115.64         117.45         113.44         115.00
# May 11, 2013         117.70         118.68         113.01         115.24
# May 10, 2013         112.80         122.00         111.55         117.20
# May 09, 2013         113.20         113.46         109.26         112.67
# May 08, 2013         109.60         115.78         109.60         113.57
# May 07, 2013         112.25         113.44          97.70         111.50
# May 06, 2013         115.98         124.66         106.64         112.30
# May 05, 2013         112.90         118.80         107.14         115.91
# May 04, 2013          98.10         115.00          92.50         112.50
# May 03, 2013         106.25         108.13          79.10          97.75
# May 02, 2013         116.38         125.60          92.28         105.21
# May 01, 2013         139.00         139.89         107.72         116.99
# Apr 30, 2013         144.00         146.93         134.05         139.00
# Apr 29, 2013         134.44         147.49         134.00         144.54
# Apr 28, 2013         135.30         135.98         132.10         134.21
#
#                           Volume            Market Cap
# Jun 22, 2018       5,079,810,000       115,269,000,000
# Jun 21, 2018       3,529,130,000       115,977,000,000
# Jun 20, 2018       3,888,640,000       115,804,000,000
# Jun 19, 2018       4,057,030,000       115,306,000,000
# Jun 18, 2018       4,039,200,000       111,319,000,000
# Jun 17, 2018       3,104,020,000       111,913,000,000
# Jun 16, 2018       3,194,170,000       110,359,000,000
# Jun 15, 2018       3,955,390,000       114,084,000,000
# Jun 14, 2018       5,138,710,000       108,408,000,000
# Jun 13, 2018       5,052,350,000       112,740,000,000
# Jun 12, 2018       4,654,380,000       118,007,000,000
# Jun 11, 2018       4,745,270,000       116,175,000,000
# Jun 10, 2018       5,804,840,000       128,128,000,000
# Jun 09, 2018       3,845,220,000       130,386,000,000
# Jun 08, 2018       4,227,580,000       131,271,000,000
# Jun 07, 2018       4,485,800,000       130,671,000,000
# Jun 06, 2018       4,692,260,000       130,233,000,000
# Jun 05, 2018       4,961,740,000       128,081,000,000
# Jun 04, 2018       4,993,170,000       131,847,000,000
# Jun 03, 2018       4,851,760,000       130,288,000,000
# Jun 02, 2018       4,939,300,000       128,645,000,000
# Jun 01, 2018       4,921,460,000       128,014,000,000
# May 31, 2018       5,127,130,000       126,386,000,000
# May 30, 2018       4,922,540,000       127,454,000,000
# May 29, 2018       5,662,660,000       121,636,000,000
# May 28, 2018       5,040,600,000       125,748,000,000
# May 27, 2018       4,056,520,000       125,575,000,000
# May 26, 2018       4,051,540,000       127,682,000,000
# May 25, 2018       4,867,830,000       129,470,000,000
# May 24, 2018       6,049,220,000       128,925,000,000
# ...                          ...                   ...
# May 27, 2013                   -         1,495,520,000
# May 26, 2013                   -         1,478,030,000
# May 25, 2013                   -         1,489,950,000
# May 24, 2013                   -         1,413,300,000
# May 23, 2013                   -         1,384,780,000
# May 22, 2013                   -         1,374,130,000
# May 21, 2013                   -         1,363,940,000
# May 20, 2013                   -         1,368,910,000
# May 19, 2013                   -         1,376,370,000
# May 18, 2013                   -         1,379,140,000
# May 17, 2013                   -         1,319,590,000
# May 16, 2013                   -         1,274,620,000
# May 15, 2013                   -         1,242,760,000
# May 14, 2013                   -         1,315,720,000
# May 13, 2013                   -         1,279,980,000
# May 12, 2013                   -         1,288,630,000
# May 11, 2013                   -         1,311,050,000
# May 10, 2013                   -         1,255,970,000
# May 09, 2013                   -         1,259,980,000
# May 08, 2013                   -         1,219,450,000
# May 07, 2013                   -         1,248,470,000
# May 06, 2013                   -         1,289,470,000
# May 05, 2013                   -         1,254,760,000
# May 04, 2013                   -         1,089,890,000
# May 03, 2013                   -         1,180,070,000
# May 02, 2013                   -         1,292,190,000
# May 01, 2013                   -         1,542,820,000
# Apr 30, 2013                   -         1,597,780,000
# Apr 29, 2013                   -         1,491,160,000
# Apr 28, 2013                   -         1,500,520,000
#
# [1882 rows x 6 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                           Open           High            Low          Close  \
# Date
# 2018-06-22            6,737.88       6,747.08       6,006.60       6,083.69
# 2018-06-21            6,780.09       6,810.94       6,715.17       6,729.74
# 2018-06-20            6,770.76       6,821.56       6,611.88       6,776.55
# 2018-06-19            6,742.39       6,822.50       6,709.92       6,769.94
# 2018-06-18            6,510.07       6,781.14       6,446.68       6,734.82
#
#                         Volume              Market Cap
# Date
# 2018-06-22       5,079,810,000         115,269,000,000
# 2018-06-21       3,529,130,000         115,977,000,000
# 2018-06-20       3,888,640,000         115,804,000,000
# 2018-06-19       4,057,030,000         115,306,000,000
# 2018-06-18       4,039,200,000         111,319,000,000

# %%
df['2018-06-22']
# Out:
#                           Open           High            Low          Close  \
# Date
# 2018-06-22            6,737.88       6,747.08       6,006.60       6,083.69
#
#                         Volume              Market Cap
# Date
# 2018-06-22       5,079,810,000         115,269,000,000

# %%
df.index
# Out:
# DatetimeIndex(['2018-06-22', '2018-06-21', '2018-06-20', '2018-06-19',
#                '2018-06-18', '2018-06-17', '2018-06-16', '2018-06-15',
#                '2018-06-14', '2018-06-13',
#                ...
#                '2013-05-07', '2013-05-06', '2013-05-05', '2013-05-04',
#                '2013-05-03', '2013-05-02', '2013-05-01', '2013-04-30',
#                '2013-04-29', '2013-04-28'],
#               dtype='datetime64[ns]', name='Date', length=1882, freq=None)

# %%
df.columns
# Out:
# Index(['               Open', '          High', '          Low',
#        '         Close', '          Volume', '             Market Cap'],
#       dtype='object')

# %%
plt.plot(df.index,df['          High'])

# %%
df['          High']
# Out:
# Date
# 2018-06-22         6,747.08
# 2018-06-21         6,810.94
# 2018-06-20         6,821.56
# 2018-06-19         6,822.50
# 2018-06-18         6,781.14
# 2018-06-17         6,589.11
# 2018-06-16         6,592.49
# 2018-06-15         6,681.08
# 2018-06-14         6,707.14
# 2018-06-13         6,631.66
# 2018-06-12         6,907.96
# 2018-06-11         6,910.18
# 2018-06-10         7,499.55
# 2018-06-09         7,683.58
# 2018-06-08         7,698.19
# 2018-06-07         7,741.27
# 2018-06-06         7,680.43
# 2018-06-05         7,643.23
# 2018-06-04         7,753.82
# 2018-06-03         7,754.89
# 2018-06-02         7,695.83
# 2018-06-01         7,604.73
# 2018-05-31         7,608.90
# 2018-05-30         7,573.77
# 2018-05-29         7,526.42
# 2018-05-28         7,419.05
# 2018-05-27         7,381.74
# 2018-05-26         7,595.16
# 2018-05-25         7,659.14
# 2018-05-24         7,738.60
#                   ...
# 2013-05-27           135.47
# 2013-05-26           136.00
# 2013-05-25           133.22
# 2013-05-24           133.85
# 2013-05-23           126.93
# 2013-05-22           124.00
# 2013-05-21           123.00
# 2013-05-20           123.62
# 2013-05-19           124.50
# 2013-05-18           125.25
# 2013-05-17           125.30
# 2013-05-16           118.76
# 2013-05-15           115.81
# 2013-05-14           119.80
# 2013-05-13           118.70
# 2013-05-12           117.45
# 2013-05-11           118.68
# 2013-05-10           122.00
# 2013-05-09           113.46
# 2013-05-08           115.78
# 2013-05-07           113.44
# 2013-05-06           124.66
# 2013-05-05           118.80
# 2013-05-04           115.00
# 2013-05-03           108.13
# 2013-05-02           125.60
# 2013-05-01           139.89
# 2013-04-30           146.93
# 2013-04-29           147.49
# 2013-04-28           135.98
# Name:           High, Length: 1882, dtype: object

# %%
plt.plot(df['          High'])

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(df.index,df['          High'])

# %%
df.index
# Out:
# DatetimeIndex(['2018-06-22', '2018-06-21', '2018-06-20', '2018-06-19',
#                '2018-06-18', '2018-06-17', '2018-06-16', '2018-06-15',
#                '2018-06-14', '2018-06-13',
#                ...
#                '2013-05-07', '2013-05-06', '2013-05-05', '2013-05-04',
#                '2013-05-03', '2013-05-02', '2013-05-01', '2013-04-30',
#                '2013-04-29', '2013-04-28'],
#               dtype='datetime64[ns]', name='Date', length=1882, freq=None)

# %%
df['          High'].head(55)
# Out:
# Date
# 2018-06-22         6,747.08
# 2018-06-21         6,810.94
# 2018-06-20         6,821.56
# 2018-06-19         6,822.50
# 2018-06-18         6,781.14
# 2018-06-17         6,589.11
# 2018-06-16         6,592.49
# 2018-06-15         6,681.08
# 2018-06-14         6,707.14
# 2018-06-13         6,631.66
# 2018-06-12         6,907.96
# 2018-06-11         6,910.18
# 2018-06-10         7,499.55
# 2018-06-09         7,683.58
# 2018-06-08         7,698.19
# 2018-06-07         7,741.27
# 2018-06-06         7,680.43
# 2018-06-05         7,643.23
# 2018-06-04         7,753.82
# 2018-06-03         7,754.89
# 2018-06-02         7,695.83
# 2018-06-01         7,604.73
# 2018-05-31         7,608.90
# 2018-05-30         7,573.77
# 2018-05-29         7,526.42
# 2018-05-28         7,419.05
# 2018-05-27         7,381.74
# 2018-05-26         7,595.16
# 2018-05-25         7,659.14
# 2018-05-24         7,738.60
# 2018-05-23         8,054.66
# 2018-05-22         8,423.25
# 2018-05-21         8,557.52
# 2018-05-20         8,562.41
# 2018-05-19         8,372.06
# 2018-05-18         8,274.12
# 2018-05-17         8,445.54
# 2018-05-16         8,508.43
# 2018-05-15         8,836.19
# 2018-05-14         8,881.12
# 2018-05-13         8,773.55
# 2018-05-12         8,664.86
# 2018-05-11         9,052.96
# 2018-05-10         9,396.04
# 2018-05-09         9,374.76
# 2018-05-08         9,462.75
# 2018-05-07         9,665.85
# 2018-05-06         9,940.14
# 2018-05-05         9,964.50
# 2018-05-04         9,779.20
# 2018-05-03         9,798.33
# 2018-05-02         9,256.52
# 2018-05-01         9,255.88
# 2018-04-30         9,477.14
# 2018-04-29         9,531.49
# Name:           High, dtype: object

# %%
sample_plot = df['          High'].head(5)

# %%
plt.plot(sample_plot)

# %%
sns.tsplot(data=sample_plot,time=sample_plot.index,value=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-49118f2ebb7d> in <module>()
# ----> 1 sns.tsplot(sample_plot)
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\seaborn\timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     282         # Bootstrap the data for confidence intervals
#     283         boot_data = algo.bootstrap(df_c.values, n_boot=n_boot,
# --> 284                                    axis=0, func=estimator)
#     285         cis = [utils.ci(boot_data, v, axis=0) for v in ci]
#     286         central_data = estimator(df_c.values, axis=0)
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      74         resampler = rs.randint(0, n, n)
#      75         sample = [a.take(resampler, axis=0) for a in args]
# ---> 76         boot_dist.append(func(*sample, **func_kwargs))
#      77     return np.array(boot_dist)
#      78
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2907
#    2908     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2909                           out=out, **kwargs)
#    2910
#    2911
#
# ~\Miniconda3\envs\machinelearning\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
# ---> 73                 ret, rcount, out=ret, casting='unsafe', subok=False)
#      74         if is_float16_result and out is None:
#      75             ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
sample_plot.values
# Out:
# array(['     6,747.08', '     6,810.94', '     6,821.56', '     6,822.50',
#        '     6,781.14'], dtype=object)
